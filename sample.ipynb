# %%
# %pip install tensorflow_io

# %%
import os
import matplotlib.pyplot as plt
from pathlib import Path
import tensorflow as tf
import tensorflow_io as tfio
import IPython.display as ipd
import numpy as np

# %% [markdown]
# ## Load Audio to Jupyter

# %%
def load_audio(file_path):
    audio_binary = tf.io.read_file(file_path)
    audio, sample_rate = tf.audio.decode_wav(audio_binary)
    waveform = tf.squeeze(audio, axis=-1)
    return waveform, sample_rate.numpy()

def load_audio_files(path: str, label:str):

    dataset = []
    walker = sorted(str(p) for p in Path(path).glob(f'*.wav'))

    for i, file_path in enumerate(walker):
        path, filename = os.path.split(file_path)
        speaker, _ = os.path.splitext(filename)
        # speaker_id,version,gender,age,reason = speaker.split("-")
        sp = speaker.split("-")
        speaker_id = sp[0]
        gender = sp[2]
        age =sp[3]


        # Load audio
        waveform, sample_rate = load_audio(file_path)
        dataset.append([waveform, sample_rate, label, speaker_id, gender,age])

    return dataset

# %% [markdown]
# ## Prepare Data

# %%
trainset_speechcommands_hungry = load_audio_files('./data/hungry', 'hungry')
trainset_speechcommands_tired = load_audio_files('./data/tired', 'tired')

print(f'Length of hungry dataset: {len(trainset_speechcommands_hungry)}')
print(f'Length of tire dataset: {len(trainset_speechcommands_tired)}')
# Out:
# Length of hungry dataset: 10
# Length of tire dataset: 10

# %%
hungry_waveform = trainset_speechcommands_hungry[0][0]
hungry_sample_rate = trainset_speechcommands_hungry[0][1]
print(f'Hungry Waveform: {hungry_waveform}')
print(f'Hungry Sample Rate: {hungry_sample_rate}')
print(f'Label: {trainset_speechcommands_hungry[0][2]}')
print(f'Hungry ID: {trainset_speechcommands_hungry[0][3]}')
# Out:
# Hungry Waveform: [ 0.          0.          0.         ... -0.00332642 -0.00045776
#   0.00100708]
# Hungry Sample Rate: 8000
# Label: hungry
# Hungry ID: 0D1AD73E_4C5E_45F3_85C4_9A3CB71E8856_1430742197

# %% [markdown]
# ## Waveform plot

# %%
timescale = np.arange(hungry_waveform .shape[0])
plt.figsize=(12, 8)
plt.plot(timescale, hungry_waveform .numpy())
plt.show()

# %%
print(tf.shape(hungry_waveform))
# Out:
# tf.Tensor([56000], shape=(1,), dtype=int32)

# %% [markdown]
# ## Spectrogram

# %%
def get_spectrogram(waveform):

    frame_length = 255
    frame_step = 128
    # Padding for files with less than 16000 samples
    zero_padding = tf.zeros([56000] - tf.shape(waveform), dtype=tf.float32)

    # Concatenate audio with padding so that all audio clips will be of the same length
    waveform = tf.cast(waveform, tf.float32)
    equal_length_waveform = tf.concat([waveform, zero_padding], 0)

    # # Option 1: Use tfio to get the spectrogram
    # spect = tfio.audio.spectrogram(input=equal_length_waveform, nfft=frame_length, window=frame_length, stride=frame_step)

    # Option 2: Use tf.signal processing to get the Short-time Fourier transform (stft)
    spectrogram = tf.signal.stft(equal_length_waveform, frame_length=frame_length, frame_step=frame_step)
    spectrogram = tf.abs(spectrogram)

    return spectrogram

# %%
spectrogram = get_spectrogram(hungry_waveform)

print('Label:', '้hungry')
print('Waveform shape:', hungry_waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
# print('Spect shape:', spect.shape)
print('Audio playback')
ipd.Audio(hungry_waveform.numpy(), rate=8000)
# Out:
# Label: ้hungry
# Waveform shape: (56000,)
# Spectrogram shape: (436, 129)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax, title):
    # Convert to frequencies to log scale and transpose so that the time is
    # represented in the x-axis (columns).
    log_spec = np.log(spectrogram.T)
    height = log_spec.shape[0]
    width = log_spec.shape[1]
    X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
    Y = range(height)
    ax.pcolormesh(X, Y, log_spec)
    ax.set_xlim([0, 56000])
    ax.set_title(title)

fig, ax = plt.subplots()
plot_spectrogram(spectrogram.numpy(), ax, 'Spectrogram 1')
plt.show()

# fig, ax = plt.subplots()
# plot_spectrogram(spect.numpy(), ax, 'Spectrogram 2')
# plt.show()
# Out:
# C:\Users\Near\AppData\Local\Temp/ipykernel_13024/54335444.py:4: RuntimeWarning: divide by zero encountered in log
#   log_spec = np.log(spectrogram.T)
# C:\Users\Near\AppData\Local\Temp/ipykernel_13024/54335444.py:9: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax.pcolormesh(X, Y, log_spec)

# %% [markdown]
# ##  Create Spectrogram image for classification

# %%
def create_images(dataset, label_dir):
    # make directory
    test_directory = f'./data/test/{label_dir}/'
    train_directory = f'./data/train/{label_dir}/'

    os.makedirs(test_directory, mode=0o777, exist_ok=True)
    os.makedirs(train_directory, mode=0o777, exist_ok=True)

    for i, data in enumerate(dataset):

        waveform = data[0]
        spectrogram, spect = get_spectrogram(waveform)

        # Split test and train images by 30%
        if i % 3 == 0:
            plt.imsave(f'./data/test/{label_dir}/spec_img{i}.png', spectrogram.numpy(), cmap='gray')
        else:
            plt.imsave(f'./data/train/{label_dir}/spec_img{i}.png', spectrogram.numpy(), cmap='gray')

# %%
create_images(trainset_speechcommands_hungry, 'hungry')
create_images(trainset_speechcommands_tired, 'tired')

# %% [markdown]
# ### Build the model

# %%
train_directory = './data/train/'
test_directory = './data/test/'

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_directory, labels='inferred', label_mode='int', image_size=(256, 256), seed=321,
    validation_split=0.3, subset='validation')

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_directory, labels='inferred', label_mode='int', image_size=(256, 256),
    validation_split=None, subset=None)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 12 files belonging to 2 classes.
# Using 3 files for validation.
# Found 8 files belonging to 2 classes.
# ['hungry', 'tired']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18944/2916741159.py in <module>
#       3     for i in range(9):
#       4         ax = plt.subplot(3, 3, i + 1)
# ----> 5         plt.imshow(images[i].numpy().astype("uint8"))
#       6         plt.title(class_names[labels[i]])
#       7         plt.axis("off")
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    7184 def raise_from_not_ok_status(e, name):
#    7185   e.message += (" name: " + name if name is not None else "")
# -> 7186   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7187
#    7188
#
# InvalidArgumentError: slice index 3 of dimension 0 out of bounds. [Op:StridedSlice] name: strided_slice/

# %% [markdown]
# ## Create Model

# %%
num_classes = 2
img_height = 256
img_width = 256

model = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes)
])

# %%
learning_rate =  0.001

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# optimizer = tf.keras.optimizers.SGD(learning_rate)
optimizer = tf.keras.optimizers.Adadelta(learning_rate)
metrics = ['accuracy']
model.compile(optimizer, loss_fn, metrics)

# %%
# Set the epocks
epochs = 80
print('\nFitting:')

# Train the model.
history = model.fit(train_ds, epochs=epochs)
# Out:
# Fitting:
# Epoch 1/80
# 1/1 [==============================] - 0s 370ms/step - loss: 0.6949 - accuracy: 0.3333
# Epoch 2/80
# 1/1 [==============================] - 0s 103ms/step - loss: 0.6944 - accuracy: 0.3333
# Epoch 3/80
# 1/1 [==============================] - 0s 96ms/step - loss: 0.6938 - accuracy: 0.3333
# Epoch 4/80
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6933 - accuracy: 0.3333
# Epoch 5/80
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6928 - accuracy: 0.3333
# Epoch 6/80
# 1/1 [==============================] - 0s 110ms/step - loss: 0.6923 - accuracy: 0.3333
# Epoch 7/80
# 1/1 [==============================] - 0s 108ms/step - loss: 0.6918 - accuracy: 0.3333
# Epoch 8/80
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6913 - accuracy: 0.6667
# Epoch 9/80
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6908 - accuracy: 0.6667
# Epoch 10/80
# 1/1 [==============================] - 0s 87ms/step - loss: 0.6903 - accuracy: 0.6667
# Epoch 11/80
# 1/1 [==============================] - 0s 102ms/step - loss: 0.6898 - accuracy: 0.6667
# Epoch 12/80
# 1/1 [==============================] - 0s 92ms/step - loss: 0.6893 - accuracy: 1.0000
# Epoch 13/80
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6888 - accuracy: 1.0000
# Epoch 14/80
# 1/1 [==============================] - 0s 106ms/step - loss: 0.6883 - accuracy: 1.0000
# Epoch 15/80
# 1/1 [==============================] - 0s 111ms/step - loss: 0.6878 - accuracy: 1.0000
# Epoch 16/80
# 1/1 [==============================] - 0s 116ms/step - loss: 0.6873 - accuracy: 1.0000
# Epoch 17/80
# 1/1 [==============================] - 0s 107ms/step - loss: 0.6868 - accuracy: 1.0000
# Epoch 18/80
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6863 - accuracy: 1.0000
# Epoch 19/80
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6858 - accuracy: 1.0000
# Epoch 20/80
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6853 - accuracy: 1.0000
# Epoch 21/80
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6848 - accuracy: 1.0000
# Epoch 22/80
# 1/1 [==============================] - 0s 91ms/step - loss: 0.6843 - accuracy: 1.0000
# Epoch 23/80
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6838 - accuracy: 1.0000
# Epoch 24/80
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6833 - accuracy: 1.0000
# Epoch 25/80
# 1/1 [==============================] - 0s 107ms/step - loss: 0.6828 - accuracy: 1.0000
# Epoch 26/80
# 1/1 [==============================] - 0s 102ms/step - loss: 0.6824 - accuracy: 1.0000
# Epoch 27/80
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6819 - accuracy: 1.0000
# Epoch 28/80
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6814 - accuracy: 1.0000
# Epoch 29/80
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6810 - accuracy: 1.0000
# Epoch 30/80
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6805 - accuracy: 1.0000
# Epoch 31/80
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6801 - accuracy: 1.0000
# Epoch 32/80
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6796 - accuracy: 1.0000
# Epoch 33/80
# 1/1 [==============================] - 0s 107ms/step - loss: 0.6791 - accuracy: 1.0000
# Epoch 34/80
# 1/1 [==============================] - 0s 116ms/step - loss: 0.6787 - accuracy: 1.0000
# Epoch 35/80
# 1/1 [==============================] - 0s 110ms/step - loss: 0.6782 - accuracy: 1.0000
# Epoch 36/80
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6778 - accuracy: 1.0000
# Epoch 37/80
# 1/1 [==============================] - 0s 106ms/step - loss: 0.6773 - accuracy: 1.0000
# Epoch 38/80
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6768 - accuracy: 1.0000
# Epoch 39/80
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6764 - accuracy: 1.0000
# Epoch 40/80
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6759 - accuracy: 1.0000
# Epoch 41/80
# 1/1 [==============================] - 0s 97ms/step - loss: 0.6755 - accuracy: 1.0000
# Epoch 42/80
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6750 - accuracy: 1.0000
# Epoch 43/80
# 1/1 [==============================] - 0s 105ms/step - loss: 0.6745 - accuracy: 1.0000
# Epoch 44/80
# 1/1 [==============================] - 0s 116ms/step - loss: 0.6741 - accuracy: 1.0000
# Epoch 45/80
# 1/1 [==============================] - 0s 118ms/step - loss: 0.6736 - accuracy: 1.0000
# Epoch 46/80
# 1/1 [==============================] - 0s 106ms/step - loss: 0.6732 - accuracy: 1.0000
# Epoch 47/80
# 1/1 [==============================] - 0s 103ms/step - loss: 0.6727 - accuracy: 1.0000
# Epoch 48/80
# 1/1 [==============================] - 0s 102ms/step - loss: 0.6723 - accuracy: 1.0000
# Epoch 49/80
# 1/1 [==============================] - 0s 116ms/step - loss: 0.6718 - accuracy: 1.0000
# Epoch 50/80
# 1/1 [==============================] - 0s 165ms/step - loss: 0.6714 - accuracy: 1.0000
# Epoch 51/80
# 1/1 [==============================] - 0s 119ms/step - loss: 0.6709 - accuracy: 1.0000
# Epoch 52/80
# 1/1 [==============================] - 0s 131ms/step - loss: 0.6705 - accuracy: 1.0000
# Epoch 53/80
# 1/1 [==============================] - 0s 126ms/step - loss: 0.6700 - accuracy: 1.0000
# Epoch 54/80
# 1/1 [==============================] - 0s 119ms/step - loss: 0.6696 - accuracy: 1.0000
# Epoch 55/80
# 1/1 [==============================] - 0s 113ms/step - loss: 0.6691 - accuracy: 1.0000
# Epoch 56/80
# 1/1 [==============================] - 0s 112ms/step - loss: 0.6687 - accuracy: 1.0000
# Epoch 57/80
# 1/1 [==============================] - 0s 106ms/step - loss: 0.6683 - accuracy: 1.0000
# Epoch 58/80
# 1/1 [==============================] - 0s 143ms/step - loss: 0.6678 - accuracy: 1.0000
# Epoch 59/80
# 1/1 [==============================] - 0s 166ms/step - loss: 0.6674 - accuracy: 1.0000
# Epoch 60/80
# 1/1 [==============================] - 0s 176ms/step - loss: 0.6669 - accuracy: 1.0000
# Epoch 61/80
# 1/1 [==============================] - 0s 180ms/step - loss: 0.6665 - accuracy: 1.0000
# Epoch 62/80
# 1/1 [==============================] - 0s 172ms/step - loss: 0.6660 - accuracy: 1.0000
# Epoch 63/80
# 1/1 [==============================] - 0s 135ms/step - loss: 0.6656 - accuracy: 1.0000
# Epoch 64/80
# 1/1 [==============================] - 0s 135ms/step - loss: 0.6652 - accuracy: 1.0000
# Epoch 65/80
# 1/1 [==============================] - 0s 115ms/step - loss: 0.6647 - accuracy: 1.0000
# Epoch 66/80
# 1/1 [==============================] - 0s 105ms/step - loss: 0.6643 - accuracy: 1.0000
# Epoch 67/80
# 1/1 [==============================] - 0s 104ms/step - loss: 0.6638 - accuracy: 1.0000
# Epoch 68/80
# 1/1 [==============================] - 0s 110ms/step - loss: 0.6634 - accuracy: 1.0000
# Epoch 69/80
# 1/1 [==============================] - 0s 102ms/step - loss: 0.6630 - accuracy: 1.0000
# Epoch 70/80
# 1/1 [==============================] - 0s 102ms/step - loss: 0.6625 - accuracy: 1.0000
# Epoch 71/80
# 1/1 [==============================] - 0s 105ms/step - loss: 0.6621 - accuracy: 1.0000
# Epoch 72/80
# 1/1 [==============================] - 0s 111ms/step - loss: 0.6616 - accuracy: 1.0000
# Epoch 73/80
# 1/1 [==============================] - 0s 104ms/step - loss: 0.6612 - accuracy: 1.0000
# Epoch 74/80
# 1/1 [==============================] - 0s 104ms/step - loss: 0.6607 - accuracy: 1.0000
# Epoch 75/80
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6603 - accuracy: 1.0000
# Epoch 76/80
# 1/1 [==============================] - 0s 100ms/step - loss: 0.6599 - accuracy: 1.0000
# Epoch 77/80
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6594 - accuracy: 1.0000
# Epoch 78/80
# 1/1 [==============================] - 0s 101ms/step - loss: 0.6590 - accuracy: 1.0000
# Epoch 79/80
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6585 - accuracy: 1.0000
# Epoch 80/80
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6581 - accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_37 (Rescaling)    (None, 256, 256, 3)       0
#
#  conv2d_111 (Conv2D)         (None, 256, 256, 16)      448
#
#  max_pooling2d_111 (MaxPooli  (None, 128, 128, 16)     0
#  ng2D)
#
#  conv2d_112 (Conv2D)         (None, 128, 128, 32)      4640
#
#  max_pooling2d_112 (MaxPooli  (None, 64, 64, 32)       0
#  ng2D)
#
#  conv2d_113 (Conv2D)         (None, 64, 64, 64)        18496
#
#  max_pooling2d_113 (MaxPooli  (None, 32, 32, 64)       0
#  ng2D)
#
#  flatten_37 (Flatten)        (None, 65536)             0
#
#  dense_74 (Dense)            (None, 128)               8388736
#
#  dense_75 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 8,412,578
# Trainable params: 8,412,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
correct = 0
batch_size = 0
for batch_num, (X, Y) in enumerate(test_ds):
    batch_size = len(Y)
    pred = model.predict(X)
    for i in range(batch_size):
        predicted = np.argmax(pred[i], axis=-1)
        actual = Y[i]
        # print(f'predicted {predicted}, actual {actual}')
        if predicted == actual:
            correct += 1
    break

print(f'Number correct: {correct} out of {batch_size}')
print(f'Accuracy {correct / batch_size}')
# Out:
# Number correct: 6 out of 8
# Accuracy 0.75
