# %% [markdown]
# <a href="https://colab.research.google.com/github/ny147/infant-classification/blob/nice/sample_one_class_with_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install tensorflow_io
# Out:
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.25.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.4 MB)
#      |████████████████████████████████| 23.4 MB 2.0 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.25.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_io) (0.25.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.25.0

# %%
# !pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 4.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.8.1
#     Uninstalling imbalanced-learn-0.8.1:
#       Successfully uninstalled imbalanced-learn-0.8.1
# Successfully installed imbalanced-learn-0.9.0

# %%
import os
import librosa, librosa.display
import matplotlib.pyplot as plt
from pathlib import Path
import tensorflow as tf
import tensorflow_io as tfio
import IPython.display as ipd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
path = '/content/drive/My Drive/Infant/new/'
#iris = pd.read_csv(path+"Iris.csv")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Load Audio to Jupyter

# %%
def load_audio(file_path):
    waveform, sample_rate = librosa.load(file_path)
    return waveform, sample_rate

def load_audio_files(path: str, label:str):

    dataset = []
    walker = sorted(str(p) for p in Path(path).glob(f'*.wav'))
    for i, file_path in enumerate(walker):
        path, filename = os.path.split(file_path)
        speaker, _ = os.path.splitext(filename)
        # speaker_id,version,gender,age,reason = speaker.split("-")
        #sp = speaker.split("-")
        #speaker_id = sp[0]
        #gender = sp[2]
        #age =sp[3]


        # Load audio
        waveform, sample_rate = load_audio(file_path)
        dataset.append([waveform, sample_rate])
        #dataset.append([waveform, sample_rate, label, speaker_id, gender,age])

    return dataset

# %% [markdown]
# ## Prepare Data

# %%
trainset_speechcommands_hungry = load_audio_files('./data/hungry', 'hungry')
trainset_speechcommands_burping = load_audio_files('./data/burping', 'burping')
trainset_speechcommands_tired = load_audio_files('./data/tired', 'tired')
trainset_speechcommands_belly_pain = load_audio_files('./data/belly_pain', 'belly_pain')
trainset_speechcommands_discomfort = load_audio_files('./data/discomfort', 'discomfort')

# %%
print(f'Length of hungry dataset: {len(trainset_speechcommands_hungry)}')
print(f'Length of burping dataset: {len(trainset_speechcommands_burping)}')
print(f'Length of tired dataset: {len(trainset_speechcommands_tired)}')
print(f'Length of belly_pain dataset: {len(trainset_speechcommands_belly_pain)}')
print(f'Length of discomfort dataset: {len(trainset_speechcommands_discomfort)}')
# Out:
# Length of hungry dataset: 382
# Length of burping dataset: 8
# Length of tired dataset: 24
# Length of belly_pain dataset: 16
# Length of discomfort dataset: 27

# %%
hungry_waveform = trainset_speechcommands_hungry[0][0]
hungry_sample_rate = trainset_speechcommands_hungry[0][1]
print(f'Yes Waveform: {hungry_waveform}')
print(f'Yes Sample Rate: {hungry_sample_rate}')
#print(f'Yes Label: {trainset_speechcommands_hungry[0][2]}')
#print(f'Yes ID: {trainset_speechcommands_hungry[0][3]}')
# Out:
# Yes Waveform: [ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -2.9080665e-02
#  -2.0946175e-02 -9.9853482e-03]
# Yes Sample Rate: 22050

# %% [markdown]
# ## Waveform plot

# %%
timescale = np.arange(hungry_waveform .shape[0])
plt.figsize=(12, 8)
plt.plot(timescale, hungry_waveform)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-8891b6987094> in <module>()
# ----> 1 timescale = np.arange(hungry_waveform .shape[0])
#       2 plt.figsize=(12, 8)
#       3 plt.plot(timescale, hungry_waveform)
#       4 plt.show()
#
# NameError: name 'hungry_waveform' is not defined

# %%
import IPython.display as ipd
ipd.Audio(hungry_waveform, rate=hungry_sample_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-2ed968838575> in <module>()
#       1 import IPython.display as ipd
# ----> 2 ipd.Audio(hungry_waveform, rate=hungry_sample_rate)
#
# NameError: name 'hungry_waveform' is not defined

# %%
print(tf.shape(hungry_waveform))
# Out:
# tf.Tensor([148176], shape=(1,), dtype=int32)

# %% [markdown]
# ## Spectrogram

# %%
def get_spectrogram(waveform):

    frame_length = 255
    frame_step = 128
    # Padding for files with less than 16000 samples
    # zero_padding = tf.zeros([56000] - tf.shape(waveform), dtype=tf.float32)
    zero_padding = tf.zeros([60000] - tf.shape(waveform), dtype=tf.float32)
    
    # Concatenate audio with padding so that all audio clips will be of the same length
    waveform = tf.cast(waveform, tf.float32)
    equal_length_waveform = tf.concat([waveform, zero_padding], 0)

    # Option 1: Use tfio to get the spectrogram
    spect = tfio.audio.spectrogram(input=equal_length_waveform, nfft=frame_length, window=frame_length, stride=frame_step)

    # Option 2: Use tf.signal processing to get the Short-time Fourier transform (stft)
    spectrogram = tf.signal.stft(equal_length_waveform, frame_length=frame_length, frame_step=frame_step)
    spectrogram = tf.abs(spectrogram)

    return spectrogram, spect

# %%
def get_spectrogram2(waveform,sample):
    fast_fourier_transf = np.fft.fft(waveform)
    
    magnitude = np.abs(fast_fourier_transf)
    
    frequency = np.linspace(0, sample, len(magnitude))
    
    left_mag = magnitude[:int(len(magnitude)/2)]
    left_freq = frequency[:int(len(frequency)/2)]
    
    n_fft = 128
    
    hop_length = 32    
    audio_stft = librosa.core.stft(waveform, hop_length=hop_length, n_fft=n_fft)
    
    # gathering the absolute values for all values in our audio_stft 
    spectrogram = np.abs(audio_stft)
    
    # Converting the amplitude to decibels
    log_spectro = librosa.power_to_db(spectrogram)
    
    return log_spectro

# %%
#spectrogram, spect = get_spectrogram(hungry_waveform)
log_sp = get_spectrogram2(hungry_waveform,hungry_sample_rate)

# %%
plt.figure(figsize=(20, 5))
#librosa.display.specshow(log_sp,sr=hungry_sample_rate, x_axis='time',y_axis='hz',hop_length=128,cmap='magma')
librosa.display.specshow(log_sp,sr=hungry_sample_rate, x_axis='time',y_axis='log',hop_length=128,cmap='magma')
#plt.colorbar(label='Amplitude')
#plt.title('Spectrogram (amp)', fontdict=dict(size=18))
plt.xlabel('Time', fontdict=dict(size=15))
plt.ylabel('Frequency', fontdict=dict(size=15))
plt.axis('off')
plt.savefig('testimg.jpg', bbox_inches="tight", pad_inches = 0)
plt.show()

# %%
def create_images(dataset, label_dir,path,num):
    # make directory
    test_directory = f'./data/test_oneclass/{path}/{label_dir}/'
    train_directory = f'./data/train_oneclass/{path}/{label_dir}/'

    os.makedirs(test_directory, mode=0o777, exist_ok=True)
    os.makedirs(train_directory, mode=0o777, exist_ok=True)
    for i, data in enumerate(dataset):
        sample_rate = data[1]
        waveform = data[0]
        spectrogram = get_spectrogram2(waveform,sample_rate)
        librosa.display.specshow(spectrogram,sr=sample_rate, x_axis='time',y_axis='log',hop_length=128,cmap='magma')
        plt.axis('off')
        # Split test and train images by 30%
        if i % 3 == 0:
            plt.savefig(f'./data/test_oneclass/{path}/{label_dir}/spec_img{i}{num}.jpg', bbox_inches="tight", pad_inches = 0)
            #plt.imsave(f'./data/test_oneclass/{path}/{label_dir}/spec_img{i}{num}.jpg', spectrogram, cmap='magma')
        else:
            plt.savefig(f'./data/train_oneclass/{path}/{label_dir}/spec_img{i}{num}.jpg', bbox_inches="tight", pad_inches = 0)
            #plt.imsave(f'./data/train_oneclass/{path}/{label_dir}/spec_img{i}{num}.jpg', spectrogram, cmap='magma')

# %%
create_images(trainset_speechcommands_hungry, 'hungry','hungry_one',0)
create_images(trainset_speechcommands_tired, 'non_hungry','hungry_one',1)
create_images(trainset_speechcommands_burping, 'non_hungry','hungry_one',2)
create_images(trainset_speechcommands_discomfort, 'non_hungry','hungry_one',3)
create_images(trainset_speechcommands_belly_pain, 'non_hungry','hungry_one',4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9985983e5388> in <module>()
# ----> 1 create_images(trainset_speechcommands_hungry, 'hungry','hungry_one',0)
#       2 create_images(trainset_speechcommands_tired, 'non_hungry','hungry_one',1)
#       3 create_images(trainset_speechcommands_burping, 'non_hungry','hungry_one',2)
#       4 create_images(trainset_speechcommands_discomfort, 'non_hungry','hungry_one',3)
#       5 create_images(trainset_speechcommands_belly_pain, 'non_hungry','hungry_one',4)
#
# NameError: name 'trainset_speechcommands_hungry' is not defined

# %%
create_images(trainset_speechcommands_tired, 'non_discomfort','discomfort_one',1)
create_images(trainset_speechcommands_burping, 'non_discomfort','discomfort_one',2)
create_images(trainset_speechcommands_discomfort, 'discomfort','discomfort_one',3)
create_images(trainset_speechcommands_belly_pain, 'non_discomfort','discomfort_one',4)

# %%
create_images(trainset_speechcommands_tired, 'tired','tired_one',1)
create_images(trainset_speechcommands_burping, 'non_tired','tired_one',2)
create_images(trainset_speechcommands_belly_pain, 'non_tired','tired_one',4)

# %%
create_images(trainset_speechcommands_burping, 'burping','burping_one',2)
create_images(trainset_speechcommands_belly_pain, 'non_burping','burping_one',4)

# %% [raw]
# ### Build the model

# %% [markdown]
# ### Build the model

# %%
train_directory = path +'/train_oneclass/hungry_one'
test_directory = path + '/test_oneclass/hungry_one'

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_directory, labels='inferred', label_mode='int', image_size=(256, 256), seed=321,
    validation_split=None, subset=None)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_directory, labels='inferred', label_mode='int', image_size=(256, 256),
    validation_split=None, subset=None)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 303 files belonging to 2 classes.
# Found 154 files belonging to 2 classes.
# ['hungry', 'non_hungry']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ## Create Model

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
x_train=[]
y_train=[]
for images, labels in train_ds.unbatch().take(-1):
    x_train.append(images.numpy())
    y_train.append(labels.numpy())

# %%
x_test=[]
y_test=[]
for images, labels in test_ds.unbatch().take(-1):
    x_test.append(images.numpy())
    y_test.append(labels.numpy())

# %%
# x_train.shape()

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)

# %%
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
plt.imshow(x_train[0].astype("uint8"))

# %%
num_classes = 2
img_height = 256
img_width = 256

# %%
 def create_weight(n_sample,n_class,n_class_sample):
     weight = n_sample/(n_class*n_class_sample)
     return weight

# %%
# np.count_nonzero(y_train == 1 )

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
#     tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
#     tf.keras.layers.MaxPooling2D((3,3)),
#     tf.keras.layers.Dropout(0.2),
#     tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
#     tf.keras.layers.MaxPooling2D((3,3)),
#     tf.keras.layers.Dropout(0.2),
#     tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
#     tf.keras.layers.MaxPooling2D((3,3)),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])

# %%
# learning_rate =  0.002
# loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)
# # loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# # optimizer = tf.keras.optimizers.SGD(learning_rate)
# #optimizer = tf.keras.optimizers.Adadelta(learning_rate)
# #optimizer = tf.keras.optimizers.Adamax(learning_rate)
# optimizer = tf.keras.optimizers.Adam(learning_rate)# modify weight in Adam
# metrics = ['accuracy']
# model.compile (optimizer = optimizer,loss =  loss_fn,metrics = metrics)

# %%
# Set the epocks
# ทำ stop + validation
# epochs = 20
# history = model.fit(x_train,y_train,epochs=epochs,
#                     validation_data=(x_val, y_val), shuffle=True)

# %%
class_weights = {0:0, 1:0}
class_count = np.array([254,49])
for i in range(num_classes):
    class_weights[i]=create_weight(303,num_classes,class_count[i])

# %%
from sklearn.model_selection import KFold

# Model configuration
learning_rate =  0.002
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)
#loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
# optimizer = tf.keras.optimizers.SGD(learning_rate)
#optimizer = tf.keras.optimizers.Adadelta(learning_rate)
#optimizer = tf.keras.optimizers.Adamax(learning_rate)
optimizer = tf.keras.optimizers.Adam(learning_rate)# modify weight in Adam
epochs = 20
metrics = ['accuracy']
#numberofK-fold
num_folds = 10
# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []

# Merge inputs and targets
inputs = x_train
targets = y_train

# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(inputs, targets):

    # Define the model architecture
    model = tf.keras.Sequential([
        tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
        tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])


    # Compile the model
    model.compile (optimizer = optimizer,loss =  loss_fn,metrics = metrics)


    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    # Fit data to model
    history = model.fit(inputs[train], targets[train],
                        epochs=epochs,class_weight = class_weights)

    # Generate generalization metrics
    scores = model.evaluate(inputs[test], targets[test], verbose=0)

    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    # Increase fold number
    fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 9/9 [==============================] - 17s 2s/step - loss: 0.7939 - accuracy: 0.6324
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6928 - accuracy: 0.8382
# Epoch 3/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6915 - accuracy: 0.8382
# Epoch 4/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6835 - accuracy: 0.8382
# Epoch 5/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6674 - accuracy: 0.7574
# Epoch 6/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6494 - accuracy: 0.5882
# Epoch 7/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6347 - accuracy: 0.5110
# Epoch 8/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6242 - accuracy: 0.4449
# Epoch 9/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6065 - accuracy: 0.5294
# Epoch 10/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5936 - accuracy: 0.4301
# Epoch 11/20
# 9/9 [==============================] - 12s 1s/step - loss: 0.5893 - accuracy: 0.4485
# Epoch 12/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5792 - accuracy: 0.5257
# Epoch 13/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5580 - accuracy: 0.5257
# Epoch 14/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5799 - accuracy: 0.5331
# Epoch 15/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5752 - accuracy: 0.5809
# Epoch 16/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5590 - accuracy: 0.4743
# Epoch 17/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5476 - accuracy: 0.4963
# Epoch 18/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5492 - accuracy: 0.5551
# Epoch 19/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5554 - accuracy: 0.4596
# Epoch 20/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5421 - accuracy: 0.5331
# Score for fold 1: loss of 0.5612215399742126; accuracy of 51.61290168762207%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/20
# 9/9 [==============================] - 12s 1s/step - loss: 1.0534 - accuracy: 0.5257
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.7082 - accuracy: 0.5662
# Epoch 3/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6817 - accuracy: 0.4963
# Epoch 4/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6663 - accuracy: 0.4853
# Epoch 5/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6963 - accuracy: 0.5294
# Epoch 6/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6858 - accuracy: 0.2721
# Epoch 7/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6969 - accuracy: 0.2169
# Epoch 8/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6861 - accuracy: 0.2868
# Epoch 9/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6713 - accuracy: 0.3199
# Epoch 10/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6496 - accuracy: 0.5000
# Epoch 11/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6437 - accuracy: 0.5699
# Epoch 12/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6276 - accuracy: 0.5147
# Epoch 13/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6172 - accuracy: 0.4779
# Epoch 14/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5974 - accuracy: 0.5294
# Epoch 15/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5953 - accuracy: 0.5662
# Epoch 16/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5655 - accuracy: 0.6029
# Epoch 17/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5577 - accuracy: 0.6103
# Epoch 18/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5722 - accuracy: 0.5919
# Epoch 19/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5966 - accuracy: 0.5625
# Epoch 20/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6098 - accuracy: 0.5147
# Score for fold 2: loss of 0.7980644702911377; accuracy of 29.032257199287415%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.9907 - accuracy: 0.6434
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6848 - accuracy: 0.5846
# Epoch 3/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6875 - accuracy: 0.5221
# Epoch 4/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6808 - accuracy: 0.3529
# Epoch 5/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6695 - accuracy: 0.3235
# Epoch 6/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6593 - accuracy: 0.4669
# Epoch 7/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6620 - accuracy: 0.3676
# Epoch 8/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6587 - accuracy: 0.3860
# Epoch 9/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6367 - accuracy: 0.4375
# Epoch 10/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6208 - accuracy: 0.5404
# Epoch 11/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6139 - accuracy: 0.4853
# Epoch 12/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6241 - accuracy: 0.4154
# Epoch 13/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6029 - accuracy: 0.4228
# Epoch 14/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6011 - accuracy: 0.4412
# Epoch 15/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5880 - accuracy: 0.4743
# Epoch 16/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5782 - accuracy: 0.5331
# Epoch 17/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5660 - accuracy: 0.4559
# Epoch 18/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5635 - accuracy: 0.5551
# Epoch 19/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5473 - accuracy: 0.5110
# Epoch 20/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.5393 - accuracy: 0.5956
# Score for fold 3: loss of 0.4891373813152313; accuracy of 67.7419364452362%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/20
# 9/9 [==============================] - 11s 1s/step - loss: 1.1583 - accuracy: 0.5458
# Epoch 2/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6936 - accuracy: 0.3077
# Epoch 3/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6922 - accuracy: 0.2015
# Epoch 4/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6925 - accuracy: 0.8388
# Epoch 5/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 6/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6926 - accuracy: 0.8388
# Epoch 7/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6925 - accuracy: 0.8388
# Epoch 8/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 9/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6928 - accuracy: 0.8388
# Epoch 10/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 11/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 12/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6925 - accuracy: 0.8388
# Epoch 13/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6927 - accuracy: 0.8388
# Epoch 14/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 15/20
# 9/9 [==============================] - 19s 2s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 16/20
# 9/9 [==============================] - 15s 2s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 17/20
# 9/9 [==============================] - 15s 2s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 18/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 19/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 20/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6923 - accuracy: 0.8388
# Score for fold 4: loss of 0.6898053288459778; accuracy of 83.33333134651184%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/20
# 9/9 [==============================] - 12s 1s/step - loss: 1.0607 - accuracy: 0.7436
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 3/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6933 - accuracy: 0.8095
# Epoch 4/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1685
# Epoch 5/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1612
# Epoch 6/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 7/20
# 9/9 [==============================] - 14s 2s/step - loss: 0.6924 - accuracy: 0.2747
# Epoch 8/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 9/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6925 - accuracy: 0.8388
# Epoch 10/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 11/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 12/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.8388
# Epoch 13/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.2857
# Epoch 14/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 15/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 16/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 17/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 18/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 19/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 20/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Score for fold 5: loss of 0.6964314579963684; accuracy of 16.66666716337204%
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Epoch 1/20
# 9/9 [==============================] - 12s 1s/step - loss: 1.2426 - accuracy: 0.3590
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6814 - accuracy: 0.1538
# Epoch 3/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6806 - accuracy: 0.1538
# Epoch 4/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6797 - accuracy: 0.1538
# Epoch 5/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6795 - accuracy: 0.8462
# Epoch 6/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6794 - accuracy: 0.8462
# Epoch 7/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6793 - accuracy: 0.8462
# Epoch 8/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6793 - accuracy: 0.8462
# Epoch 9/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6791 - accuracy: 0.8462
# Epoch 10/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6791 - accuracy: 0.8462
# Epoch 11/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6791 - accuracy: 0.8462
# Epoch 12/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6791 - accuracy: 0.8462
# Epoch 13/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6792 - accuracy: 0.8462
# Epoch 14/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6793 - accuracy: 0.8462
# Epoch 15/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6792 - accuracy: 0.8462
# Epoch 16/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6792 - accuracy: 0.8462
# Epoch 17/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6792 - accuracy: 0.8462
# Epoch 18/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6795 - accuracy: 0.8462
# Epoch 19/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6793 - accuracy: 0.8462
# Epoch 20/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6792 - accuracy: 0.8462
# Score for fold 6: loss of 0.6846376657485962; accuracy of 76.66666507720947%
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Epoch 1/20
# 9/9 [==============================] - 12s 1s/step - loss: 1.0231 - accuracy: 0.7582
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.7070 - accuracy: 0.2344
# Epoch 3/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7053 - accuracy: 0.1685
# Epoch 4/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7050 - accuracy: 0.1685
# Epoch 5/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7049 - accuracy: 0.1685
# Epoch 6/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7047 - accuracy: 0.1685
# Epoch 7/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7049 - accuracy: 0.1685
# Epoch 8/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7046 - accuracy: 0.1685
# Epoch 9/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7049 - accuracy: 0.1685
# Epoch 10/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 11/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 12/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7047 - accuracy: 0.1685
# Epoch 13/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7049 - accuracy: 0.1685
# Epoch 14/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7047 - accuracy: 0.1685
# Epoch 15/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7062 - accuracy: 0.1685
# Epoch 16/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7047 - accuracy: 0.1685
# Epoch 17/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7047 - accuracy: 0.1685
# Epoch 18/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7046 - accuracy: 0.1685
# Epoch 19/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 20/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7046 - accuracy: 0.1685
# Score for fold 7: loss of 0.7067420482635498; accuracy of 10.000000149011612%
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Epoch 1/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.8393 - accuracy: 0.3443
# Epoch 2/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7050 - accuracy: 0.1685
# Epoch 3/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7061 - accuracy: 0.1685
# Epoch 4/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7051 - accuracy: 0.1685
# Epoch 5/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7056 - accuracy: 0.1685
# Epoch 6/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 7/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 8/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 9/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7047 - accuracy: 0.1685
# Epoch 10/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7046 - accuracy: 0.1685
# Epoch 11/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 12/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 13/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7050 - accuracy: 0.1685
# Epoch 14/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 15/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7052 - accuracy: 0.1685
# Epoch 16/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7047 - accuracy: 0.1685
# Epoch 17/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7050 - accuracy: 0.1685
# Epoch 18/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7048 - accuracy: 0.1685
# Epoch 19/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7046 - accuracy: 0.1685
# Epoch 20/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.7051 - accuracy: 0.1685
# Score for fold 8: loss of 0.7142089605331421; accuracy of 10.000000149011612%
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Epoch 1/20
# 9/9 [==============================] - 11s 1s/step - loss: 1.0329 - accuracy: 0.5018
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6936 - accuracy: 0.8388
# Epoch 3/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6929 - accuracy: 0.8388
# Epoch 4/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6925 - accuracy: 0.8388
# Epoch 5/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 6/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 7/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6928 - accuracy: 0.8388
# Epoch 8/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Epoch 9/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6925 - accuracy: 0.7839
# Epoch 10/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6931 - accuracy: 0.8388
# Epoch 11/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6926 - accuracy: 0.8388
# Epoch 12/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6922 - accuracy: 0.8388
# Epoch 13/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.6227
# Epoch 14/20
# 9/9 [==============================] - 13s 1s/step - loss: 0.6926 - accuracy: 0.4322
# Epoch 15/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6923 - accuracy: 0.4212
# Epoch 16/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.3810
# Epoch 17/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6923 - accuracy: 0.6777
# Epoch 18/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6925 - accuracy: 0.8388
# Epoch 19/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6928 - accuracy: 0.8388
# Epoch 20/20
# 9/9 [==============================] - 10s 1s/step - loss: 0.6924 - accuracy: 0.8388
# Score for fold 9: loss of 0.6849492192268372; accuracy of 83.33333134651184%
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Epoch 1/20
# 9/9 [==============================] - 12s 1s/step - loss: 2.2756 - accuracy: 0.2344
# Epoch 2/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6927 - accuracy: 0.1612
# Epoch 3/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6928 - accuracy: 0.1612
# Epoch 4/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1612
# Epoch 5/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6932 - accuracy: 0.1612
# Epoch 6/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6926 - accuracy: 0.1612
# Epoch 7/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6927 - accuracy: 0.1612
# Epoch 8/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6926 - accuracy: 0.1612
# Epoch 9/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1612
# Epoch 10/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1612
# Epoch 11/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1612
# Epoch 12/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1612
# Epoch 13/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 14/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.3407
# Epoch 15/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6925 - accuracy: 0.2198
# Epoch 16/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 17/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6923 - accuracy: 0.1612
# Epoch 18/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6924 - accuracy: 0.1612
# Epoch 19/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6922 - accuracy: 0.3700
# Epoch 20/20
# 9/9 [==============================] - 11s 1s/step - loss: 0.6925 - accuracy: 0.8388
# Score for fold 10: loss of 0.6901566982269287; accuracy of 83.33333134651184%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.5612215399742126 - Accuracy: 51.61290168762207%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.7980644702911377 - Accuracy: 29.032257199287415%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.4891373813152313 - Accuracy: 67.7419364452362%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6898053288459778 - Accuracy: 83.33333134651184%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6964314579963684 - Accuracy: 16.66666716337204%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 0.6846376657485962 - Accuracy: 76.66666507720947%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 0.7067420482635498 - Accuracy: 10.000000149011612%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 0.7142089605331421 - Accuracy: 10.000000149011612%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 0.6849492192268372 - Accuracy: 83.33333134651184%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 0.6901566982269287 - Accuracy: 83.33333134651184%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 51.172042191028595 (+- 30.164287139474606)
# > Loss: 0.6715354770421982
# ------------------------------------------------------------------------

# %%
plt.plot(loss_per_fold,label = 'loss')
#plt.plot(history.history['val_loss'],label = 'val_loss')
plt.legend()
plt.show()

# %%
plt.plot(acc_per_fold,label = 'accuracy')
#plt.plot(history.history['val_accuracy'],label = 'val_accuracy')
plt.legend()
plt.show()

# %%
def binary_transform(pred):
    if pred > 0.5:
        predicted = 1
    else:
        predicted = 0
    return predicted

# %%
pred = model.predict(x_test)

vfunc = np.vectorize(binary_transform)
y_pred = vfunc(y_pred)
actual = x_test

print(f'Number correct: {correct} out of {sum_size}')
print(f'Accuracy {correct / sum_size}')
# Out:
# Number correct: 128 out of 154
# Accuracy 0.8311688311688312

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,target_names=["Hungry","Non_hungry"]))
# Out:
#               precision    recall  f1-score   support
#
#       Hungry       0.83      1.00      0.91       128
#   Non_hungry       0.00      0.00      0.00        26
#
#     accuracy                           0.83       154
#    macro avg       0.42      0.50      0.45       154
# weighted avg       0.69      0.83      0.75       154
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=class_names)
disp.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show>
