# %%
import os
import librosa, librosa.display
import matplotlib.pyplot as plt
from pathlib import Path
import tensorflow as tf
import IPython.display as ipd
import numpy as np
from scipy.fftpack import fft
import shutil
from pydub import AudioSegment

from functools import partial
#import ftransc
# Out:
# c:\Users\acer\anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
def load_audio(file_path):
    waveform, sample_rate = librosa.load(file_path)
    return waveform, sample_rate

def load_audio_files(path: str, label:str):

    dataset = []
    walker = sorted(str(p) for p in Path(path).glob(f'*.wav'))
    for i, file_path in enumerate(walker):
        path, filename = os.path.split(file_path)
        speaker, _ = os.path.splitext(filename)
        # speaker_id,version,gender,age,reason = speaker.split("-")
        #sp = speaker.split("-")
        #speaker_id = sp[0]
        #gender = sp[2]
        #age =sp[3]


        # Load audio
        waveform, sample_rate = load_audio(file_path)
        audio_segment = AudioSegment.from_file(file_path)
        dataset.append([waveform, sample_rate,audio_segment])
        #dataset.append([waveform, sample_rate, label, speaker_id, gender,age])

    return dataset

# %%
hungry_data = load_audio_files('./cleandata/hungry/', 'hungry')
tired_data = load_audio_files('./cleandata/tired/', 'hungry')
burping_data = load_audio_files('./cleandata/burping/', 'hungry')
belly_pain_data = load_audio_files('./cleandata/belly_pain/', 'hungry')
discomfort_data = load_audio_files('./cleandata/discomfort/', 'hungry')

# %%
hungry_waveform = hungry_data[0][0]
hungry_sample_rate = hungry_data[0][1]

# %%
def fast_furior_transform(waveform,sample):
    yf = np.abs(librosa.stft(waveform))
    img = librosa.display.specshow(librosa.amplitude_to_db(yf),y_axis='log')
    plt.colorbar()

# %%
def Spectrogram(waveform,sample):
    waveform = librosa.stft(waveform)
    waveformdb = librosa.power_to_db(abs(waveform))
    plt.figure(figsize=(15, 3))
    librosa.display.specshow(waveformdb, sr=sample, x_axis='time', y_axis='log',cmap = 'magma')
    plt.colorbar()
    
    return waveformdb

# %%
def mel_spectrogram(waveform,sample,n_fft=2048,hop_length=128):
    #fast_fourier_transf = np.fft.fft(waveform)
   
    audio_stft = librosa.feature.melspectrogram(y=waveform,n_fft=n_fft,hop_length=hop_length)
    log_spectro = librosa.power_to_db(audio_stft)
    librosa.display.specshow(log_spectro, sr=sample, x_axis='time', y_axis='fft',cmap = 'magma')
    
    
    return log_spectro

# %%
def rms(waveform,sample):
    # Get RMS value from each frame's magnitude value
    S, phase = librosa.magphase(librosa.stft(waveform))
    rms = librosa.feature.rms(S=S)
    # Plot the RMS energy
    fig, ax = plt.subplots(figsize=(15, 6), nrows=2, sharex=True)
    times = librosa.times_like(rms)
    ax[0].semilogy(times, rms[0], label='RMS Energy')
    ax[0].set(xticks=[])
    ax[0].legend()
    ax[0].label_outer()
    data =librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(data,y_axis='log', x_axis='time', ax=ax[1],cmap = 'magma')
    ax[1].set(title='log Power spectrogram')
    return data

# %%
def zero_crossing(waveform,sample):
    zcrs = librosa.feature.zero_crossing_rate(waveform)
    data = librosa.power_to_db(zcrs)
    print(f"Zero crossing rate: {sum(librosa.zero_crossings(waveform))}")
    plt.figure(figsize=(15, 3))
    plt.plot(zcrs[0])
    plt.title('Action Rock')
    return data

# %%
feature = []
label = []

# %%
def mel_freq(waveform,sample):
    mfccs = librosa.feature.mfcc(waveform, sr=sample,dct_type = 2)
    data=np.mean(librosa.feature.mfcc(waveform,sr=sample,n_mfcc=100).T,axis=0)
    #data = librosa.power_to_db(mfccs)
    # Displaying  the MFCCs:
    #librosa.display.specshow(mfccs, sr=sample, x_axis='hz',cmap = 'magma')
    return data,mfccs

# %%
def create_feature(dataset,typeimg,labeltype):
    # make directory
    for i, data in enumerate(dataset):
        sample_rate = data[1]
        waveform = data[0]
        #print(sample_rate,waveform)
        if typeimg == 'Spectrogram':
            spectrogram = Spectrogram(waveform,sample_rate)
        elif typeimg == 'mel_spectrogram':
            spectrogram = mel_spectrogram(waveform,sample_rate)
        elif typeimg == 'rms':
            spectrogram = rms(waveform,sample_rate)
        elif typeimg == 'zero_crossing':
            spectrogram = zero_crossing(waveform,sample_rate)
        elif typeimg == 'mel_freq':
            mean_mfcc,spectrogram = mel_freq(waveform,sample_rate)
        #librosa.display.specshow(spectrogram,sr=sample_rate, x_axis='time')
        
        #plt.axis('off')
        # Split test and train images by 30%
        #plt.savefig(f'./img_data/{typeimg}/{path}/{label_dir}/spec_img{i}{num}.jpg', bbox_inches="tight", pad_inches = 0)
            #plt.imsave(f'./data/test_oneclass/{path}/{label_dir}/spec_img{i}{num}.jpg', spectrogram, cmap='magma')
        feature.append(mean_mfcc)
        label.append(labeltype)
    #return feature,label

# %%
create_feature(hungry_data,typeimg='mel_freq',labeltype = 0)
create_feature(tired_data,typeimg='mel_freq',labeltype = 1)
create_feature(burping_data,typeimg='mel_freq',labeltype = 1)
create_feature(discomfort_data,typeimg='mel_freq',labeltype = 1)
create_feature(belly_pain_data,typeimg='mel_freq',labeltype = 1)
# Out:
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -2.9080665e-02
#  -2.0946175e-02 -9.9853482e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -2.9080665e-02
#  -2.0946175e-02 -9.9853482e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 2.0793739e-06  1.7721575e-06 -5.7010152e-07 ... -4.2220512e-03
#  -3.9947988e-03 -2.2493436e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 2.0793739e-06  1.7721575e-06 -5.7010152e-07 ... -4.2220512e-03
#  -3.9947988e-03 -2.2493436e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -3.4407005e-03
#  -2.2694590e-03 -9.8553114e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -3.4407005e-03
#  -2.2694590e-03 -9.8553114e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -1.6445403e-03
#   4.6817423e-03  5.0573861e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -1.6445403e-03
#   4.6817423e-03  5.0573861e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  1.1536498e-02
#   8.6022522e-03  4.1930084e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  1.1536498e-02
#   8.6022522e-03  4.1930084e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -9.4807637e-04
#  -6.8386056e-04 -2.8473159e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -9.4807637e-04
#  -6.8386056e-04 -2.8473159e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  1.9373126e-02
#   1.6731879e-02  8.9109596e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  1.9373126e-02
#   1.6731879e-02  8.9109596e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  3.6796242e-02
#   2.1057941e-02  7.5933663e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  3.6796242e-02
#   2.1057941e-02  7.5933663e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -3
as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[-0.00038403 -0.00075927 -0.00069732 ... -0.00650694 -0.00414154
#  -0.00163664] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[-0.00038403 -0.00075927 -0.00069732 ... -0.00650694 -0.00414154
#  -0.00163664] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.0318506e-06  9.2244221e-07 -2.4674588e-07 ... -3.2119614e-03
#  -2.4904776e-03 -1.2200780e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.0318506e-06  9.2244221e-07 -2.4674588e-07 ... -3.2119614e-03
#  -2.4904776e-03 -1.2200780e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[1.5001424e-06 1.7430800e-06 3.4593455e-08 ... 8.7827194e-04 5.0553231e-04
#  2.3430992e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[1.5001424e-06 1.7430800e-06 3.4593455e-08 ... 8.7827194e-04 5.0553231e-04
#  2.3430992e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2098130e-06  9.0492887e-07 -4.7820839e-07 ...  4.7888845e-02
#   3.6959033e-02  1.8500404e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2098130e-06  9.0492887e-07 -4.7820839e-07 ...  4.7888845e-02
#   3.6959033e-02  1.8500404e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[0.         0.         0.         ... 0.00913283 0.00709071 0.00358567] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[0.         0.         0.         ... 0.00913283 0.00709071 0.00358567] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -5.9785591e-03
#  -5.0158123e-03 -2.6171156e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ... -5.9785591e-03
#  -5.0158123e-03 -2.6171156e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[-1.9216411e-04  6.8480127e-05  3.8098509e-04 ... -2.4385195e-02
#  -1.9063454e-02 -9.6030058e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[-1.9216411e-04  6.8480127e-05  3.8098509e-04 ... -2.4385195e-02
#  -1.9063454e-02 -9.6030058e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.0455078e-05  2.0626496e-04  3.2086764e-04 ... -9.1936447e-05
#  -5.8081397e-04 -5.9179578e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.0455078e-05  2.0626496e-04  3.2086764e-04 ... -9.1936447e-05
#  -5.8081397e-04 -5.9179578e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  8.8087760e-02
#   7.5029381e-02  3.8653098e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\acer\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Pass y=[ 1.2662281e-06  1.4249257e-06 -1.5742867e-08 ...  8.8087760e-02
#   7.5029381e-02  3.8653098e-02] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score
import seaborn as sb

# %%
feature = np.array(feature)
label = np.array(label)

# %%
label.shape
# Out:
# (457,)

# %%
x_train,x_test,y_train,y_test = train_test_split(feature,label,test_size = 0.3,random_state = 48)

# %%
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(input_shape=(100,), units= 200,activation='relu'))
model.add(tf.keras.layers.Dense(200,activation='relu'))
model.add(tf.keras.layers.Dense(200,activation='relu'))
model.add(tf.keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
def create_weight(n_sample,n_class,n_class_sample):
    weight = n_sample/(n_class*n_class_sample)
    return weight

# %%
num_classes= 2

# %%
class_weights = {0:0, 1:0}
class_count = np.array([254,49])
for i in range(num_classes):
    class_weights[i]=create_weight(303,num_classes,class_count[i])

# %%
hist=model.fit(x_train,y_train,epochs=100,validation_split=0.3,class_weight = class_weights)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 17ms/step - loss: 4.6638 - accuracy: 0.6054 - val_loss: 5.7667 - val_accuracy: 0.1771
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6129 - accuracy: 0.5291 - val_loss: 2.5538 - val_accuracy: 0.2083
# Epoch 3/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.2233 - accuracy: 0.5561 - val_loss: 0.6836 - val_accuracy: 0.8333
# Epoch 4/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3560 - accuracy: 0.5291 - val_loss: 0.7341 - val_accuracy: 0.8333
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.
# Epoch 42/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.9865 - val_loss: 0.9507 - val_accuracy: 0.8125
# Epoch 43/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0747 - accuracy: 0.9865 - val_loss: 0.9618 - val_accuracy: 0.6979
# Epoch 44/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0655 - accuracy: 0.9955 - val_loss: 0.9841 - val_accuracy: 0.7083
# Epoch 45/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0790 - accuracy: 0.9776 - val_loss: 0.9134 - val_accuracy: 0.7708
# Epoch 46/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9955 - val_loss: 0.9697 - val_accuracy: 0.7917
# Epoch 47/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 0.9865 - val_loss: 1.0150 - val_accuracy: 0.8021
# Epoch 48/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0612 - accuracy: 0.9776 - val_loss: 0.9976 - val_accuracy: 0.7917
# Epoch 49/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.9978 - val_accuracy: 0.7708
# Epoch 50/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0391 - accuracy: 1.0000 - val_loss: 1.0456 - val_accuracy: 0.7917
# Epoch 51/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0356 - accuracy: 0.9910 - val_loss: 1.0931 - val_accuracy: 0.8021
# Epoch 52/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0376 - accuracy: 0.9910 - val_loss: 1.0743 - val_accuracy: 0.8021
# Epoch 53/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 1.0717 - val_accuracy: 0.7604
# Epoch 54/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 1.1256 - val_accuracy: 0.8125
# Epoch 55/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 0.9910 - val_loss: 1.1110 - val_accuracy: 0.7708
# Epoch 56/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0363 - accuracy: 0.9910 - val_loss: 1.1616 - val_accuracy: 0.7292
# Epoch 57/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0435 - accuracy: 0.9910 - val_loss: 1.1511 - val_accuracy: 0.7188
# Epoch 58/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9955 - val_loss: 1.1717 - val_accuracy: 0.8125
# Epoch 59/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0247 - accuracy: 0.9955 - val_loss: 1.1935 - val_accuracy: 0.8125
# Epoch 60/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 1.1605 - val_accuracy: 0.7604
# Epoch 61/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.2343 - val_accuracy: 0.8125
# Epoch 62/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 1.2101 - val_accuracy: 0.7708
# Epoch 63/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 1.2606 - val_accuracy: 0.8021
# Epoch 64/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 1.2378 - val_accuracy: 0.7604
# Epoch 65/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.2543 - val_accuracy: 0.8021
# Epoch 66/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.2480 - val_accuracy: 0.7708
# Epoch 67/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.2832 - val_accuracy: 0.8021
# Epoch 68/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.2651 - val_accuracy: 0.7708
# Epoch 69/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.2879 - val_accuracy: 0.8021
# Epoch 70/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.3096 - val_accuracy: 0.7812
# Epoch 71/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.3187 - val_accuracy: 0.8021
# Epoch 72/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.3183 - val_accuracy: 0.7812
# Epoch 73/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.3425 - val_accuracy: 0.8021
# Epoch 74/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.3667 - val_accuracy: 0.8021
# Epoch 75/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.3437 - val_accuracy: 0.7708
# Epoch 76/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.3556 - val_accuracy: 0.8021
# Epoch 77/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.3659 - val_accuracy: 0.7812
# Epoch 78/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.4052 - val_accuracy: 0.7917
# Epoch 79/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.4170 - val_accuracy: 0.7917
# Epoch 80/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.4095 - val_accuracy: 0.7917
# Epoch 81/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.4274 - val_accuracy: 0.8021
# Epoch 82/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.4159 - val_accuracy: 0.7812
# Epoch 83/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.4355 - val_accuracy: 0.7812
# Epoch 84/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.4592 - val_accuracy: 0.7917
# Epoch 85/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.4578 - val_accuracy: 0.8021
# Epoch 86/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.4451 - val_accuracy: 0.7812
# Epoch 87/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.4823 - val_accuracy: 0.7812
# Epoch 88/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.4924 - val_accuracy: 0.8021
# Epoch 89/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.4891 - val_accuracy: 0.7812
# Epoch 90/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.4832 - val_accuracy: 0.7917
# Epoch 91/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.5267 - val_accuracy: 0.8021
# Epoch 92/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.5058 - val_accuracy: 0.7917
# Epoch 93/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.5094 - val_accuracy: 0.7917
# Epoch 94/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.5389 - val_accuracy: 0.8125
# Epoch 95/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.5428 - val_accuracy: 0.7917
# Epoch 96/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.5508 - val_accuracy: 0.7917
# Epoch 97/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.5518 - val_accuracy: 0.7917
# Epoch 98/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.5593 - val_accuracy: 0.7917
# Epoch 99/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.5652 - val_accuracy: 0.7917
# Epoch 100/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.5690 - val_accuracy: 0.7917

# %%
Y_pred=model.predict(x_test)
Y_pred=(Y_pred>0.5)*1

# %%
plt.figure(figsize=(10,8),dpi=80)
sb.heatmap(confusion_matrix(y_test,Y_pred),annot=True,cmap='Blues')
plt.title('1 signifies dog sounds and 0 signifies cat sounds \n'+'Accuracy:'+str(accuracy_score(y_test,Y_pred)))
plt.show()
